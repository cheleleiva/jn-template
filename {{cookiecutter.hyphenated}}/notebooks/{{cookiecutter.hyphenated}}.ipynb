# %% [markdown]
# # {{cookiecutter.app_name}}
#
# {{cookiecutter.description}}
#
#
# Author: {{cookiecutter.author_name}}

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('../scripts')

import polars as pl

from config import DATA_DIR, EXPORT_DIR

# %% [markdown]
# ## Load Data

# %%
df = pl.read_csv(DATA_DIR/"filename.csv")
df.head()
